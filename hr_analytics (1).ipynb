# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\mahaj\OneDrive\Desktop\btech 1'st semester\Generative AI\hrdataset.csv")
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay      Bonus  Unit_Price    Volume  openingbalance  \
# 0       5089.00   2035.600   254.4500    3.770000  21226600            3.75
# 1       5698.12   2279.248   284.9060    3.740000  10462800            3.85
# 2       5896.65   2358.660   294.8325    3.890000  18761000            4.23
# 3       6125.12   2450.048   306.2560    4.350000  66130600            4.26
# 4       6245.00   2498.000   312.2500    4.340000  26868200            4.79
# ...         ...        ...        ...         ...       ...             ...
# 4995  180696.80  72278.720  9034.8400  629.511067   3927000             NaN
# 4996  185685.90  74274.360  9284.2950  627.841071   6031900             NaN
# 4997  192636.80  77054.720  9631.8400  625.860033   7949400             NaN
# 4998  195970.70  78388.280  9798.5350  629.510005   3908400             NaN
# 4999  199970.74  79988.296  9998.5370  627.839984   6003300             NaN
#
#       closingbalance         low  Unit_Sales Total_Sales  Months  \
# 0           3.760000    3.650000       18.25        18.8       0
# 1           3.680000    3.650000       18.40       18.85       0
# 2           4.290000    3.720000       18.70        18.9       0
# 3           4.310000    3.830000       18.75          19       0
# 4           4.410000    4.080000       18.80       19.05       1
# ...              ...         ...         ...         ...     ...
# 4995      293.838840  310.955001      117.80                  72
# 4996      301.311314  309.610028      118.60                  72
# 4997      306.040009  303.483494      118.60                  72
# 4998      308.579987  312.432438      118.65                  72
# 4999      312.307316  311.081089      118.75                  72
#
#                 Education
# 0     High School or less
# 1     High School or less
# 2     High School or less
# 3     High School or less
# 4     High School or less
# ...                   ...
# 4995                   PG
# 4996                   PG
# 4997                   PG
# 4998                   PG
# 4999                   PG
#
# [5000 rows x 20 columns]

# %%
df1=df.copy()
df1
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay      Bonus  Unit_Price    Volume  openingbalance  \
# 0       5089.00   2035.600   254.4500    3.770000  21226600            3.75
# 1       5698.12   2279.248   284.9060    3.740000  10462800            3.85
# 2       5896.65   2358.660   294.8325    3.890000  18761000            4.23
# 3       6125.12   2450.048   306.2560    4.350000  66130600            4.26
# 4       6245.00   2498.000   312.2500    4.340000  26868200            4.79
# ...         ...        ...        ...         ...       ...             ...
# 4995  180696.80  72278.720  9034.8400  629.511067   3927000             NaN
# 4996  185685.90  74274.360  9284.2950  627.841071   6031900             NaN
# 4997  192636.80  77054.720  9631.8400  625.860033   7949400             NaN
# 4998  195970.70  78388.280  9798.5350  629.510005   3908400             NaN
# 4999  199970.74  79988.296  9998.5370  627.839984   6003300             NaN
#
#       closingbalance         low  Unit_Sales Total_Sales  Months  \
# 0           3.760000    3.650000       18.25        18.8       0
# 1           3.680000    3.650000       18.40       18.85       0
# 2           4.290000    3.720000       18.70        18.9       0
# 3           4.310000    3.830000       18.75          19       0
# 4           4.410000    4.080000       18.80       19.05       1
# ...              ...         ...         ...         ...     ...
# 4995      293.838840  310.955001      117.80                  72
# 4996      301.311314  309.610028      118.60                  72
# 4997      306.040009  303.483494      118.60                  72
# 4998      308.579987  312.432438      118.65                  72
# 4999      312.307316  311.081089      118.75                  72
#
#                 Education
# 0     High School or less
# 1     High School or less
# 2     High School or less
# 3     High School or less
# 4     High School or less
# ...                   ...
# 4995                   PG
# 4996                   PG
# 4997                   PG
# 4998                   PG
# 4999                   PG
#
# [5000 rows x 20 columns]

# %%
df.head(10)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
# 5    Male         0           No   Yes        Two year     Yes     No   23
# 6    Male         0          Yes    No        Two year     Yes     No   23
# 7  Female         0           No   Yes        One year     Yes     No   24
# 8  Female         1           No   Yes  Month-to-month     Yes    Yes   24
# 9    Male         0           No   Yes  Month-to-month     Yes     No   43
#
#        Salary     Base_pay       Bonus  Unit_Price    Volume  openingbalance  \
# 0  5089.00000  2035.600000  254.450000        3.77  21226600          3.7500
# 1  5698.12000  2279.248000  284.906000        3.74  10462800          3.8500
# 2  5896.65000  2358.660000  294.832500        3.89  18761000          4.2300
# 3  6125.12000  2450.048000  306.256000        4.35  66130600          4.2600
# 4  6245.00000  2498.000000  312.250000        4.34  26868200          4.7900
# 5  6444.23000  2577.692000  322.211500        4.37  29869600          5.8800
# 6  6455.50000  2582.200000  322.775000        4.42  25239200          6.0925
# 7  6458.35722  2583.342888  322.917861        4.44  28307500          6.1000
# 8  6529.23000  2611.692000  326.461500        4.45  24295600          6.1500
# 9  6682.33000  2672.932000  334.116500        4.41  17671600          6.2600
#
#    closingbalance   low  Unit_Sales Total_Sales  Months            Education
# 0           3.760  3.65       18.25        18.8       0  High School or less
# 1           3.680  3.65       18.40       18.85       0  High School or less
# 2           4.290  3.72       18.70        18.9       0  High School or less
# 3           4.310  3.83       18.75          19       0  High School or less
# 4           4.410  4.08       18.80       19.05       1  High School or less
# 5           5.040  4.13       18.80        19.1       1  High School or less
# 6           5.590  4.15       18.80        19.1       1  High School or less
# 7           5.670  4.21       18.80       19.15       1         Intermediate
# 8           6.170  4.27       18.85        19.2       1         Intermediate
# 9           6.095  4.22       18.85        19.2       1         Intermediate

# %%
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# 4990  168974.5280  61235.51239  8448.726400  312.500000   317200
# 4991  169149.7070  67659.88280  8457.485350  309.660004   443500
# 4992  170372.5473  68149.01893  8518.627365  312.700012   295300
# 4993  170639.5565  68255.82259  8531.977825  314.000000   294600
# 4994  175689.3000  70275.72000  8784.465000  625.861078  7987100
# 4995  180696.8000  72278.72000  9034.840000  629.511067  3927000
# 4996  185685.9000  74274.36000  9284.295000  627.841071  6031900
# 4997  192636.8000  77054.72000  9631.840000  625.860033  7949400
# 4998  195970.7000  78388.28000  9798.535000  629.510005  3908400
# 4999  199970.7400  79988.29600  9998.537000  627.839984  6003300
#
#       openingbalance  closingbalance         low  Unit_Sales Total_Sales  \
# 4990             NaN      223.960007  307.399994      116.85     8672.45
# 4991             NaN      219.080002  302.779999      117.15      8684.8
# 4992             NaN      238.089996  308.489990      117.20
# 4993             NaN      237.899994  309.420013      117.45
# 4994             NaN      238.470001  302.048370      117.60
# 4995             NaN      293.838840  310.955001      117.80
# 4996             NaN      301.311314  309.610028      118.60
# 4997             NaN      306.040009  303.483494      118.60
# 4998             NaN      308.579987  312.432438      118.65
# 4999             NaN      312.307316  311.081089      118.75
#
#       Months Education
# 4990      72        PG
# 4991      72        PG
# 4992      72        PG
# 4993      72        PG
# 4994      72        PG
# 4995      72        PG
# 4996      72        PG
# 4997      72        PG
# 4998      72        PG
# 4999      72        PG

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.size
# Out:
# 100000

# %%
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# std      52.244022  1.620476e+07       38.361497       37.148512    36.760641
# min       1.440000  0.000000e+00        3.680000        3.680000     3.650000
# 25%      25.727500  1.283850e+06       22.098750       21.990000    21.718750
# 50%      39.205000  2.870600e+06       33.119999       33.340000    32.880001
# 75%      58.715000  6.247100e+06       51.421839       51.117500    50.415000
# max     629.511067  3.208684e+08      313.903904      313.688694   312.432438
#
#        Unit_Sales      Months
# count  5000.00000  5000.00000
# mean     64.84151    32.18480
# std      30.13968    24.63673
# min      18.25000     0.00000
# 25%      35.50000     8.00000
# 50%      70.50000    28.00000
# 75%      89.95000    55.00000
# max     118.75000    72.00000

# %%
df=df.replace(r'^\s*$',float(np.nan),regex=True)

# %%
df.tail()
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay     Bonus  Unit_Price   Volume  openingbalance  \
# 4995  180696.80  72278.720  9034.840  629.511067  3927000             NaN
# 4996  185685.90  74274.360  9284.295  627.841071  6031900             NaN
# 4997  192636.80  77054.720  9631.840  625.860033  7949400             NaN
# 4998  195970.70  78388.280  9798.535  629.510005  3908400             NaN
# 4999  199970.74  79988.296  9998.537  627.839984  6003300             NaN
#
#       closingbalance         low  Unit_Sales Total_Sales  Months Education
# 4995      293.838840  310.955001      117.80         NaN      72        PG
# 4996      301.311314  309.610028      118.60         NaN      72        PG
# 4997      306.040009  303.483494      118.60         NaN      72        PG
# 4998      308.579987  312.432438      118.65         NaN      72        PG
# 4999      312.307316  311.081089      118.75         NaN      72        PG

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
#  17  Total_Sales     4984 non-null   object
#  18  Months          5000 non-null   int64
#  19  Education       5000 non-null   object
# dtypes: float64(8), int64(4), object(8)
# memory usage: 781.4+ KB

# %%
df['Total_Sales'] = df['Total_Sales'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
#  17  Total_Sales     4984 non-null   float64
#  18  Months          5000 non-null   int64
#  19  Education       5000 non-null   object
# dtypes: float64(9), int64(4), object(7)
# memory usage: 781.4+ KB

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# Education            0
# dtype: int64

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
from sklearn.impute import KNNImputer
x=df[['Base_pay','openingbalance','Total_Sales']]

# %%
df.isnull().sum()*100/len(df)
# Out:
# Gender             0.00
# Business           0.00
# Dependancies       0.00
# Calls              0.00
# Type               0.00
# Billing            0.00
# Rating             0.00
# Age                0.00
# Salary             0.00
# Base_pay           0.46
# Bonus              0.00
# Unit_Price         0.00
# Volume             0.00
# openingbalance    29.52
# closingbalance     0.00
# low                0.00
# Unit_Sales         0.00
# Total_Sales        0.32
# Months             0.00
# Education          0.00
# dtype: float64

# %%
imputer = KNNImputer(n_neighbors=2)
x = imputer.fit_transform(x)
x
# Out:
# array([[2.03560000e+03, 3.75000000e+00, 1.88000000e+01],
#        [2.27924800e+03, 3.85000000e+00, 1.88500000e+01],
#        [2.35866000e+03, 4.23000000e+00, 1.89000000e+01],
#        ...,
#        [7.70547200e+04, 3.09164993e+02, 8.31165000e+03],
#        [7.83882800e+04, 3.09164993e+02, 8.31165000e+03],
#        [7.99882960e+04, 3.09164993e+02, 8.31165000e+03]], shape=(5000, 3))

# %%
df[['Base_pay','openingbalance','Total_Sales']]=pd.DataFrame (x, columns =['Base_pay','openingbalance','Total_Sales'])

# %%
df.isna().sum()
# Out:
# Gender            0
# Business          0
# Dependancies      0
# Calls             0
# Type              0
# Billing           0
# Rating            0
# Age               0
# Salary            0
# Base_pay          0
# Bonus             0
# Unit_Price        0
# Volume            0
# openingbalance    0
# closingbalance    0
# low               0
# Unit_Sales        0
# Total_Sales       0
# Months            0
# Education         0
# dtype: int64

# %%
degree_wise=df.Education.value_counts() #counting degree wise employee
degree_wise #degree wise employee
# Out:
# Education
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: count, dtype: int64

# %%
Gender_wise=df.Gender.value_counts() #counting total number of the employee gender wise.
Gender_wise                       # gender wise employee.
# Out:
# Gender
# Male      2528
# Female    2472
# Name: count, dtype: int64

# %%
# counting how many employees have been rated by supervisor
Rating_wise=df.Rating.value_counts() #counting the total number of ratings employee wise
Rating_wise  #rating wise
# Out:
# Rating
# No     3682
# Yes    1318
# Name: count, dtype: int64

# %%
# counting how many employees authority to call
call_wise=df.Calls.value_counts() #counting the total number of employee who has authority to call.
call_wise   #number of employee has authority to call
# Out:
# Calls
# Yes    4539
# No      461
# Name: count, dtype: int64

# %%
# counting number of people dependant on the person
Dependancies_wise=df.Dependancies.value_counts() #counting total number of people dependednt on the person.
Dependancies_wise # number of people dependent on the employee.
# Out:
# Dependancies
# No     3524
# Yes    1476
# Name: count, dtype: int64

# %%
Age_wise=df.Age.value_counts() #counting number of employess working in the company age wise.
Age_wise #age wise employee.
# Out:
# Age
# 50    256
# 53    254
# 55    248
# 54    245
# 51    244
#      ...
# 88      2
# 80      1
# 82      1
# 85      1
# 79      1
# Name: count, Length: 65, dtype: int64

# %%
#checking count of salary settlement type
Type_wise=df.Type.value_counts()   #counting employee salary settlement type.
Type_wise  #no. of employee settlement type.
# Out:
# Type
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: count, dtype: int64

# %%
#checking number of employee Subscribed to billing plans or no
Billing_wise=df.Billing.value_counts()  # counting employee who has subscribed billing plans or not.
Billing_wise #number of employee subscribed to billing plans.
# Out:
# Billing
# Yes    2956
# No     2044
# Name: count, dtype: int64

# %%
# setting a grey background 
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# Ploting subplots with numerical variables
sns.histplot(data=df, x="Salary", kde=True, color="red", ax=axs[0, 0])
sns.histplot(data=df, x="Base_pay", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df, x="Bonus", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df, x="Age", kde=True, color="black", ax=axs[1, 1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sns.histplot(data=df, x="low", kde=True, color="red", ax=axs[0])# histogram for low column 
sns.histplot(data=df, x="Total_Sales", kde=True, color="Navy", ax=axs[1])# histogram for Total_sales column
plt.show()

# %%
# setting a grey background 
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with variables
sns.boxplot(data=df, x="Salary", color="Lime", ax=axs[0, 0])# boxplot to see Distribution of salary
sns.boxplot(data=df, x="Base_pay", color="olive", ax=axs[0, 1])# boxplot to see Distribution of base_pay
sns.boxplot(data=df, x="Bonus", color="gold", ax=axs[1, 0])# boxplot to see Distribution of bonus
sns.boxplot(data=df, x="Age", color="pink", ax=axs[1, 1])# boxplot to see Distribution of age
plt.show()

# %%
# setting a grey background  
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with all variables
sns.boxplot(data=df, x="Unit_Price", color="darkred", ax=axs[0, 0])# boxplot to see outliers of unitprice 
sns.boxplot(data=df, x="Unit_Sales", color="olive", ax=axs[0, 1])# boxplot to see outliers of unit_sales
sns.boxplot(data=df, x="openingbalance", color="gold", ax=axs[1, 0])# boxplot to see outliers of openingbalance
sns.boxplot(data=df, x="closingbalance", color="teal", ax=axs[1, 1])# boxplot to see outliers of closingbalance

plt.show()

# %%
# settong a grey background  
sns.set(style="darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Ploting subplots with variables
sns.boxplot(data=df, x="low", color="red", ax=axs[0,0])# boxplot to see outliers of low column 
sns.boxplot(data=df, x="Total_Sales", color="Navy", ax=axs[0,1])# boxplot to see outliers of Total_sales column
sns.boxplot(data=df, x="Volume", color="Yellow", ax=axs[1,0])# boxplot to see outliers of volume column
sns.boxplot(data=df, x="Months", color="skyblue", ax=axs[1,1])# boxplot to see outliers of months column
plt.show()

# %%
pip install pingouin
# Out:
# Requirement already satisfied: pingouin in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (0.5.5)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (3.10.6)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (2.3.3)
# Requirement already satisfied: pandas>=1.5 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (2.3.2)
# Requirement already satisfied: pandas-flavor in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (0.7.0)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (1.7.2)
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (1.16.3)
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (0.13.2)
# Requirement already satisfied: statsmodels in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (0.14.5)
# Requirement already satisfied: tabulate in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pingouin) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mahaj\appdata\roaming\python\python313\site-packages (from pandas>=1.5->pingouin) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.5->pingouin) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\mahaj\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pingouin) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.2->pingouin) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.2->pingouin) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pingouin) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pingouin) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pingouin) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pingouin) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\mahaj\appdata\roaming\python\python313\site-packages (from matplotlib->pingouin) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pingouin) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pingouin) (3.2.4)
# Requirement already satisfied: xarray in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from pandas-flavor->pingouin) (2025.10.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from statsmodels->pingouin) (1.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
# QQ plot for Salary
import pingouin as pg 
pg.qqplot(df['Salary'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Base_Pay
pg.qqplot(df['Base_pay'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Bonus
pg.qqplot(df['Bonus'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Age
pg.qqplot(df['Age'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Unit_Price
pg.qqplot(df['Unit_Price'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Unit_Sales
pg.qqplot(df['Unit_Sales'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Openingbalance
pg.qqplot(df['openingbalance'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Closing Balance
pg.qqplot(df['closingbalance'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
# QQ plot for Low
pg.qqplot(df['low'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
df3 = df.drop(['Business'],axis = 1)# Here I remove the business column becuase this 
                                    #variable comes under categorical feature
df3.head()
# Out:
#    Gender Dependancies Calls            Type Billing Rating  Age   Salary  \
# 0  Female           No   Yes  Month-to-month      No    Yes   18  5089.00
# 1  Female           No   Yes  Month-to-month      No    Yes   19  5698.12
# 2    Male           No   Yes  Month-to-month     Yes     No   22  5896.65
# 3  Female           No   Yes  Month-to-month     Yes    Yes   21  6125.12
# 4    Male           No   Yes  Month-to-month     Yes    Yes   23  6245.00
#
#    Base_pay     Bonus  Unit_Price    Volume  openingbalance  closingbalance  \
# 0  2035.600  254.4500        3.77  21226600            3.75            3.76
# 1  2279.248  284.9060        3.74  10462800            3.85            3.68
# 2  2358.660  294.8325        3.89  18761000            4.23            4.29
# 3  2450.048  306.2560        4.35  66130600            4.26            4.31
# 4  2498.000  312.2500        4.34  26868200            4.79            4.41
#
#     low  Unit_Sales  Total_Sales  Months            Education
# 0  3.65       18.25        18.80       0  High School or less
# 1  3.65       18.40        18.85       0  High School or less
# 2  3.72       18.70        18.90       0  High School or less
# 3  3.83       18.75        19.00       0  High School or less
# 4  4.08       18.80        19.05       1  High School or less

# %%
df3_numeric = df3.select_dtypes(include='number')

# %%
# Spearman rank correlation heatmap

df3_numeric.corr(method="spearman")# selecting the method as a sperman
plt.figure(figsize=(20,8))# setting the figuresize

heatmap = sns.heatmap(df3_numeric.corr(method = 'spearman').round(3), vmin=-1, 
vmax=1, annot=True)# annot = True means writting the data value in each cell.

font2= {'family':'serif','color':'green','size':20}
plt.title("Spearman Rank Correlation",font2)
plt.show()# displaying heatmap

# %%
df3_numeric.corr(method='spearman',min_periods=1) #finding spearman co-relation.
# Out:
#                      Age    Salary  Base_pay     Bonus  Unit_Price    Volume  \
# Age             1.000000  0.202282  0.202121  0.202282    0.128266 -0.039345
# Salary          0.202282  1.000000  0.999976  1.000000    0.811713 -0.390488
# Base_pay        0.202121  0.999976  1.000000  0.999976    0.811681 -0.390427
# Bonus           0.202282  1.000000  0.999976  1.000000    0.811713 -0.390488
# Unit_Price      0.128266  0.811713  0.811681  0.811713    1.000000 -0.324230
# Volume         -0.039345 -0.390488 -0.390427 -0.390488   -0.324230  1.000000
# openingbalance -0.052919  0.453469  0.452851  0.453469    0.333408 -0.071153
# closingbalance  0.440989  0.346498  0.346409  0.346498    0.263699 -0.147108
# low             0.202040  0.999859  0.999834  0.999859    0.812412 -0.392209
# Unit_Sales      0.202268  0.999997  0.999973  0.999997    0.811735 -0.390505
# Total_Sales     0.202173  0.999965  0.999941  0.999965    0.811705 -0.390480
# Months          0.222837  0.603796  0.603766  0.603796    0.550062 -0.262077
#
#                 openingbalance  closingbalance       low  Unit_Sales  \
# Age                  -0.052919        0.440989  0.202040    0.202268
# Salary                0.453469        0.346498  0.999859    0.999997
# Base_pay              0.452851        0.346409  0.999834    0.999973
# Bonus                 0.453469        0.346498  0.999859    0.999997
# Unit_Price            0.333408        0.263699  0.812412    0.811735
# Volume               -0.071153       -0.147108 -0.392209   -0.390505
# openingbalance        1.000000       -0.037212  0.453432    0.453472
# closingbalance       -0.037212        1.000000  0.346278    0.346485
# low                   0.453432        0.346278  1.000000    0.999856
# Unit_Sales            0.453472        0.346485  0.999856    1.000000
# Total_Sales           0.453583        0.346424  0.999826    0.999963
# Months                0.185002        0.365927  0.603752    0.603779
#
#                 Total_Sales    Months
# Age                0.202173  0.222837
# Salary             0.999965  0.603796
# Base_pay           0.999941  0.603766
# Bonus              0.999965  0.603796
# Unit_Price         0.811705  0.550062
# Volume            -0.390480 -0.262077
# openingbalance     0.453583  0.185002
# closingbalance     0.346424  0.365927
# low                0.999826  0.603752
# Unit_Sales         0.999963  0.603779
# Total_Sales        1.000000  0.603748
# Months             0.603748  1.000000

# %%
 # Looking the categorical columns
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['Gender', 'Dependancies', 'Calls', 'Type', 'Billing', 'Rating', 'Education']

# %%
plt.figure(figsize=(9,8)) #size of the figure
sns.boxplot(data=df,x="Gender", y="Salary", color="Red") #plotting the box plot for Salary vs gender.
plt.title("Salary vs Gender") #plot title.
# Out:
# Text(0.5, 1.0, 'Salary vs Gender')

# %%
plt.figure(figsize=(12,8))#isze of the plot
sns.boxplot(data=df,x="Education", y="Salary", color="Green") #box plot education wise with salary
plt.title("Salary Vs Education") #title of the plot.
# Out:
# Text(0.5, 1.0, 'Salary Vs Education')

# %%
plt.figure(figsize=(12, 7)) #figure size
sns.boxplot(x='Type',y='Salary',data=df,palette='winter') #Salary vs Salary settlement type.
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_14656\817975481.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Type',y='Salary',data=df,palette='winter') #Salary vs Salary settlement type.
# <Axes: xlabel='Type', ylabel='Salary'>

# %%
plt.figure(figsize=(9, 7)) #title of the plot
sns.boxplot(x='Business',y='Salary',data=df,palette='winter') #box plot Salary vs Employee.
plt.title("Salary vs Business") #title of the plot
# Out:
# C:\Users\mahaj\AppData\Local\Temp\ipykernel_14656\3288192196.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Business',y='Salary',data=df,palette='winter') #box plot Salary vs Employee.
# Text(0.5, 1.0, 'Salary vs Business')

# %%
plt.figure(figsize=(9, 7))# size of the plot
sns.boxplot(data=df,x="Rating", y="Salary") #box plot rating vs salary
plt.title("Salary vs Rating")  #title of the salary
# Out:
# Text(0.5, 1.0, 'Salary vs Rating')

# %%
plt.figure(figsize=(9, 7)) #size of the plot
sns.boxplot(data=df,x="Dependancies", y="Salary") #box plot of dependancies vs Salary
plt.title("Salary vs Dependancies") #title of the plot
# Out:
# Text(0.5, 1.0, 'Salary vs Dependancies')

# %%
plt.figure(figsize=(9, 7)) #size of the plot
sns.boxplot(data=df,x="Billing", y="Salary") #box plot of the Billing and Salary
plt.title("Salary vs Billing")  # title of the plot.
# Out:
# Text(0.5, 1.0, 'Salary vs Billing')

# %%
#scatter plot vs salary and Base_pay
#distribution of salary on the basis of Base_Pay

plt.figure(figsize=(15,10))
plt.xlabel('Base_pay',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Base_pay vs salary',fontsize=15)

sns.scatterplot(x=df['Base_pay'],y=df['Salary'],color='black')
plt.show()

# %%
#distribution of salary on age to know the trend of salary increase according to age or not . 
plt.figure(figsize=(15,10))
plt.xlabel('Age',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('age vs salary',fontsize=15)

sns.scatterplot(x=df['Age'],y=df['Salary'],color='black')
plt.show()

# %%
#scatter plot openingbalance vs salary
#distribution of salary on the basis of openingbalance
plt.figure(figsize=(20,10))
plt.xlabel('openingbalance',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('openingbalance vs salary',fontsize=20)

sns.scatterplot(x=df['openingbalance'],y=df['Salary'],color='black')
plt.show()

# %%
#distribution of salary on Volume to know the trend of salary increase according to volume or not . 
plt.figure(figsize=(20,10))
plt.xlabel('Volume',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('Volume vs salary',fontsize=20)

sns.scatterplot(x=df['Volume'],y=df['Salary'],color='black')
plt.show()

# %%
# distribution salary on basis of bonus 
plt.figure(figsize=(20,10))
plt.xlabel('Bonus',fontsize=20)
plt.ylabel('salary',fontsize=20)
plt.title('Bonus vs salary',fontsize=20)

sns.scatterplot(x=df['Bonus'],y=df['Salary'],color='black')
plt.show()

# %%
plt.figure(figsize=(9, 7)) #size of the figure
figure=df.boxplot(column="Age") #box plot of the Age.

# %%
plt.figure(figsize=(9, 7)) #size of the plot
figure=df.boxplot(column="Salary") #box plot of the Salary.

# %%
plt.figure(figsize=(9, 7)) #size of the figure
figure=df.boxplot(column="Base_pay") #box plot of the Base_pay

# %%
plt.figure(figsize=(9, 7)) #size of the plot
figure=df.boxplot(column="Bonus") #box plot of the Bonus

# %%
plt.figure(figsize=(9, 7)) #size of the graph
figure=df.boxplot(column="Unit_Price") # box plot of the unit price.

# %%
plt.figure(figsize=(9, 7)) #size of the plot.
figure=df.boxplot(column="Volume") #box plot of the volume.

# %%
plt.figure(figsize=(9, 7)) #size of the plot
figure=df.boxplot(column="openingbalance") #box plot of the openingbalance

# %%
plt.figure(figsize=(9, 7)) #plotting the figure 
figure=df.boxplot(column="closingbalance") #box plot of the closingbalance

# %%
plt.figure(figsize=(9, 7))  #figure size
figure=df.boxplot(column="low")  #plotting box plot of lowest balance alloted to the person

# %%
plt.figure(figsize=(9, 7)) #size of the plot
figure=df.boxplot(column="Unit_Sales") #box plot of the unit sales

# %%
plt.figure(figsize=(9, 7)) #size of the plot.
figure=df.boxplot(column="Total_Sales") #box plot of the Total_sales.

# %%
plt.figure(figsize=(9, 7))  #size of the plot
figure=df.boxplot(column="Months") #box plot of the months

# %%
df3 = df.drop(['Business'],axis = 1)# Here I remove the business column becuase this variable comes under categorical feature
df3.head()
# Out:
#    Gender Dependancies Calls            Type Billing Rating  Age   Salary  \
# 0  Female           No   Yes  Month-to-month      No    Yes   18  5089.00
# 1  Female           No   Yes  Month-to-month      No    Yes   19  5698.12
# 2    Male           No   Yes  Month-to-month     Yes     No   22  5896.65
# 3  Female           No   Yes  Month-to-month     Yes    Yes   21  6125.12
# 4    Male           No   Yes  Month-to-month     Yes    Yes   23  6245.00
#
#    Base_pay     Bonus  Unit_Price    Volume  openingbalance  closingbalance  \
# 0  2035.600  254.4500        3.77  21226600            3.75            3.76
# 1  2279.248  284.9060        3.74  10462800            3.85            3.68
# 2  2358.660  294.8325        3.89  18761000            4.23            4.29
# 3  2450.048  306.2560        4.35  66130600            4.26            4.31
# 4  2498.000  312.2500        4.34  26868200            4.79            4.41
#
#     low  Unit_Sales  Total_Sales  Months            Education
# 0  3.65       18.25        18.80       0  High School or less
# 1  3.65       18.40        18.85       0  High School or less
# 2  3.72       18.70        18.90       0  High School or less
# 3  3.83       18.75        19.00       0  High School or less
# 4  4.08       18.80        19.05       1  High School or less

# %%
df3_numeric = df3.select_dtypes(include='number')
# Spearman rank correlation heatmap

df3_numeric.corr(method="spearman")# selecting the method as a sperman
plt.figure(figsize=(20,8))# setting the figuresize

heatmap = sns.heatmap(df3_numeric.corr(method = 'spearman').round(3), vmin=-1, 
vmax=1, annot=True) #annot = True means writting the data value in each cell.

font2= {'family':'serif','color':'green','size':20}
plt.title("Spearman Rank Correlation",font2)
plt.show()# displaying heatmap

# %%
# Looking to the percentage of correlation 
df3_numeric = df3.select_dtypes(include='number')
df3_numeric.corr(method='spearman')*100
# Out:
#                        Age      Salary    Base_pay       Bonus  Unit_Price  \
# Age             100.000000   20.228180   20.212073   20.228180   12.826637
# Salary           20.228180  100.000000   99.997589  100.000000   81.171311
# Base_pay         20.212073   99.997589  100.000000   99.997589   81.168113
# Bonus            20.228180  100.000000   99.997589  100.000000   81.171311
# Unit_Price       12.826637   81.171311   81.168113   81.171311  100.000000
# Volume           -3.934477  -39.048779  -39.042656  -39.048779  -32.422983
# openingbalance   -5.291931   45.346909   45.285139   45.346909   33.340773
# closingbalance   44.098882   34.649833   34.640860   34.649833   26.369923
# low              20.203950   99.985870   99.983405   99.985870   81.241207
# Unit_Sales       20.226808   99.999741   99.997324   99.999741   81.173482
# Total_Sales      20.217334   99.996520   99.994102   99.996520   81.170467
# Months           22.283665   60.379576   60.376626   60.379576   55.006199
#
#                     Volume  openingbalance  closingbalance         low  \
# Age              -3.934477       -5.291931       44.098882   20.203950
# Salary          -39.048779       45.346909       34.649833   99.985870
# Base_pay        -39.042656       45.285139       34.640860   99.983405
# Bonus           -39.048779       45.346909       34.649833   99.985870
# Unit_Price      -32.422983       33.340773       26.369923   81.241207
# Volume          100.000000       -7.115316      -14.710785  -39.220924
# openingbalance   -7.115316      100.000000       -3.721154   45.343163
# closingbalance  -14.710785       -3.721154      100.000000   34.627752
# low             -39.220924       45.343163       34.627752  100.000000
# Unit_Sales      -39.050546       45.347171       34.648512   99.985599
# Total_Sales     -39.048003       45.358275       34.642390   99.982649
# Months          -26.207721       18.500185       36.592681   60.375227
#
#                 Unit_Sales  Total_Sales      Months
# Age              20.226808    20.217334   22.283665
# Salary           99.999741    99.996520   60.379576
# Base_pay         99.997324    99.994102   60.376626
# Bonus            99.999741    99.996520   60.379576
# Unit_Price       81.173482    81.170467   55.006199
# Volume          -39.050546   -39.048003  -26.207721
# openingbalance   45.347171    45.358275   18.500185
# closingbalance   34.648512    34.642390   36.592681
# low              99.985599    99.982649   60.375227
# Unit_Sales      100.000000    99.996259   60.377897
# Total_Sales      99.996259   100.000000   60.374805
# Months           60.377897    60.374805  100.000000

# %%
# Dropping the non-required variables
dff = df.drop(columns=['Gender','Business','Dependancies','Calls','Type','Billing',
                       'Rating','Base_pay','Unit_Price','low','Unit_Sales',
                       'Total_Sales','openingbalance','closingbalance','Volume','Bonus'])
dff.head()
# Out:
#    Age   Salary  Months            Education
# 0   18  5089.00       0  High School or less
# 1   19  5698.12       0  High School or less
# 2   22  5896.65       0  High School or less
# 3   21  6125.12       0  High School or less
# 4   23  6245.00       1  High School or less

# %%
#label encoding to convert cateograical data to into numerical data

dff['Education']=dff['Education'].map({'High School or less': 0, 'Intermediate': 1, 
                                       'Graduation': 2, 'PG': 3})
#assigning high school =0,Intermediate =1 and gradaution=2

# %%
dff.head() #head of the data set after label encoding
# Out:
#    Age   Salary  Months  Education
# 0   18  5089.00       0          0
# 1   19  5698.12       0          0
# 2   22  5896.65       0          0
# 3   21  6125.12       0          0
# 4   23  6245.00       1          0

# %%
dff.info()# cross checking
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        5000 non-null   int64
#  1   Salary     5000 non-null   float64
#  2   Months     5000 non-null   int64
#  3   Education  5000 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 156.4 KB

# %%
Q1=dff.quantile(0.25).round(3) # taking lower quantile into Q2
Q3 =dff.quantile(0.75).round(3) # taking upper quarantile to Q3
IQR = Q3 - Q1 #calculating inter quantile range
print(IQR) #printing quatile range
# Out:
# Age             10.000
# Salary       33021.753
# Months          47.000
# Education        1.000
# dtype: float64

# %%
dfout = dff[~((dff < (Q1 - 1.5 * IQR)) |(dff > (Q3 + 1.5 * IQR))).any(axis=1)] #removing outliers from whole data set.
dfout.shape
# Out:
# (4833, 4)

# %%
sns.boxplot(x=dfout['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=dfout['Salary'])
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.boxplot(x=dfout['Months'])
# Out:
# <Axes: xlabel='Months'>

# %%
x =dff.drop(['Salary'],axis=1) #dropping highly co-related features.
x #new datas set.
# Out:
#       Age  Months  Education
# 0      18       0          0
# 1      19       0          0
# 2      22       0          0
# 3      21       0          0
# 4      23       1          0
# ...   ...     ...        ...
# 4995   72      72          3
# 4996   73      72          3
# 4997   74      72          3
# 4998   74      72          3
# 4999   88      72          3
#
# [5000 rows x 3 columns]

# %%
#Dependent variables to y
y = dff['Salary']
y
# Out:
# 0         5089.00
# 1         5698.12
# 2         5896.65
# 3         6125.12
# 4         6245.00
#           ...
# 4995    180696.80
# 4996    185685.90
# 4997    192636.80
# 4998    195970.70
# 4999    199970.74
# Name: Salary, Length: 5000, dtype: float64

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.3, 
                                                    random_state=0)

# %%
x_train
# Out:
#       Age  Months  Education
# 2858   45      21          2
# 1559   47       1          3
# 1441   45       1          3
# 2179   55       7          3
# 1390   44       1          2
# ...   ...     ...        ...
# 4931   63      72          3
# 3264   40      31          3
# 1653   48       2          2
# 2607   62      15          2
# 2732   68      18          2
#
# [3500 rows x 3 columns]

# %%
y_train
# Out:
# 2858    104938.82440
# 1559     88835.89005
# 1441     86903.28139
# 2179     96844.15570
# 1390     86096.55833
#             ...
# 4931    151880.35890
# 3264    110244.51700
# 1653     90043.98773
# 2607    101985.79940
# 2732    103369.50500
# Name: Salary, Length: 3500, dtype: float64

# %%
x_test
# Out:
#       Age  Months  Education
# 398    49      12          3
# 3833   39      48          2
# 4836   59      72          3
# 4572   51      68          3
# 636    53      27          3
# ...   ...     ...        ...
# 4554   50      68          3
# 4807   58      72          3
# 1073   64      63          3
# 2906   48      22          3
# 1357   43       1          3
#
# [1500 rows x 3 columns]

# %%
y_test
# Out:
# 398      64631.43297
# 3833    118137.14110
# 4836    143137.34650
# 4572    133346.50250
# 636      73049.74210
#             ...
# 4554    132723.77580
# 4807    141312.27900
# 1073     81265.54772
# 2906    105472.97890
# 1357     85510.67637
# Name: Salary, Length: 1500, dtype: float64

# %%
# data normalization with sklearn
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
# fit scaler on training data
x_train = sc.fit_transform(x_train)

# transform testing data
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.79810913, -0.45185117, -1.14142217],
#        [-0.56643739, -1.26180691,  0.79882921],
#        [-0.79810913, -1.26180691,  0.79882921],
#        ...,
#        [-0.45060152, -1.22130912, -1.14142217],
#        [ 1.17110062, -0.69483789, -1.14142217],
#        [ 1.86611582, -0.57334453, -1.14142217]], shape=(3500, 3))

# %%
x_test
# Out:
# array([[-0.33476566, -0.81633125,  0.79882921],
#        [-1.49312433,  0.64158909, -1.14142217],
#        [ 0.82359302,  1.61353598,  0.79882921],
#        ...,
#        [ 1.40277236,  1.24905589,  0.79882921],
#        [-0.45060152, -0.41135338,  0.79882921],
#        [-1.02978086, -1.26180691,  0.79882921]], shape=(1500, 3))

# %%
#machine learning techniques

# %%
from sklearn.tree import DecisionTreeRegressor
# Create and train the DecisionTree
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
accuracy = 100*(1-mape)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 8
#       4 model.fit(x_train, y_train)
#       6 y_pred = model.predict(x_test)
# ----> 8 mae = mean_absolute_error(y_test, y_pred)
#       9 mse = mean_squared_error(y_test,y_pred)
#      10 rmse = np.sqrt(mse)
#
# NameError: name 'mean_absolute_error' is not defined
